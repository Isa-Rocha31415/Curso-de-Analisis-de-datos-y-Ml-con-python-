# %% [markdown]
# # Sesión 01: Fundamentos de Python

# %% [markdown]
# ## Ejemplo 2: Variables

# %%
nombre_10= 43 #V
variable_43= 55 #V
var_nuevaNumero = 22 #NV

# %% [markdown]
# ## Ejemplo 3: Operaciones numéricas

# %%
var_1 = 4
var_2 = 10
var_3 = 6
var_4 = 8
var_5 = 2

# %%
var_1 + var_2    # Resultado esperado: 14
# Out:
# 14

# %%
var_3 - var_2  # Resultado esperado: -4
# Out:
# -4

# %%
var_3 * var_1  # Resultado esperado: 24
# Out:
# 24

# %%
var_5 + var_3  # Resultado esperado: 8
# Out:
# 8

# %%
var_4 / var_5  # Resultado esperado: 4
# Out:
# 4.0

# %% [markdown]
# ## Ejemplo 4: Tipos de Datos
#
# > Bloc con sangría
#
# > Bloc con sangría

# %%
# Este es un número entero

var_int = 4598

print(var_int)
print(type(var_int))
print("\n")

# Este es un número decimal

var_float = 369.432

print(var_float)
print(type(var_float))
print("\n")

# Esta es una string

var_string = "Soy una string"

print(var_string)
print(type(var_string))
print("\n")

# Este es un booleano

var_bool = True

print(var_bool)
print(type(var_bool))
print("\n")

# %% [markdown]
# ## Ejemplo 5: Interpolación de strings

# %%
var_1 = 15.3
var_2 = 23.4
print("Suma var_1 y la var_2")
print(var_1 +var_2)
# Out:
# Suma var_1 y la var_2
# 38.7

# %%
var_3 =34
var_4 = 24.3
suma = var_3 + var_4
print(f'La suma de var_3 y var_4 es: {suma}') #print personalizado
# Out:
# La suma de var_3 y var_4 es: 58.3

# %%
nombre_1 = "Jenny"
nombre_2 = "Marco P."

edad_1 = 110
edad_2 = 42

estrella_1 = "Woopsie Doopsies"
estrella_2 = "Omega-3"
estrella_3 = "Justin Bieber"
estrella_4 = "La Twinkle"
estrella_5 = "Rosaberta"

total_de_nombres_de_estrellas_mencionados = 5
numero_de_estrellas_deseadas = 325

# %%
print(f"{nombre_1} y {nombre_2} son grandes amigues. Les mejores. Van y vienen juntos desde hace décadas. Sí, décadas. {nombre_1} tiene {edad_1} años y {nombre_2} {edad_2}.")
print(f"Si sumas sus edades, obtienes {edad_1 + edad_2}, que curiosamente es el número de estrellas que {nombre_1} y {nombre_2} han nombrado juntos. Sus estrellas son su mayor fascinación.")
print(f"Las compraron en Best Buy en una ganga de objetos celestes. Están {estrella_1}, {estrella_2}, {estrella_3}, {estrella_4}, {estrella_5} y otras {edad_1 + edad_2 - total_de_nombres_de_estrellas_mencionados}")
print(f"estrellas más. {nombre_1} y {nombre_2} tienen planeado sobrevivir hasta el siglo XXII. ¡Cuántas estrellas más habrán de comprar y nombrar juntos! Su meta es {numero_de_estrellas_deseadas}.")
print(f"Sólo faltan {numero_de_estrellas_deseadas - edad_1 + edad_2}. ¡Vamos {nombre_1} y {nombre_2}! {nombre_1} y {nombre_2} son les mejores amigues. No hay duda alguna.")
# Out:
# Jenny y Marco P. son grandes amigues. Les mejores. Van y vienen juntos desde hace décadas. Sí, décadas. Jenny tiene 110 años y Marco P. 42.
# Si sumas sus edades, obtienes 152, que curiosamente es el número de estrellas que Jenny y Marco P. han nombrado juntos. Sus estrellas son su mayor fascinación.
# Las compraron en Best Buy en una ganga de objetos celestes. Están Woopsie Doopsies, Omega-3, Justin Bieber, La Twinkle, Rosaberta y otras 147
# estrellas más. Jenny y Marco P. tienen planeado sobrevivir hasta el siglo XXII. ¡Cuántas estrellas más habrán de comprar y nombrar juntos! Su meta es 325.
# Sólo faltan 257. ¡Vamos Jenny y Marco P.! Jenny y Marco P. son les mejores amigues. No hay duda alguna.

# %%
print(f"{nombre_1} y {nombre_2} son grandes amigues. Les mejores. Van y vienen juntos desde hace décadas. Sí, décadas. {nombre_1} tiene {edad_1} años y {nombre_2} {edad_2}." +
      f"Si sumas sus edades, obtienes {edad_1 + edad_2}, que curiosamente es el número de estrellas que {nombre_1} y {nombre_2} han nombrado juntos. Sus estrellas son su mayor fascinación." +
      f"Las compraron en Best Buy en una ganga de objetos celestes. Están {estrella_1}, {estrella_2}, {estrella_3}, {estrella_4}, {estrella_5} y otras {edad_1 + edad_2 - total_de_nombres_de_estrellas_mencionados}" +
      f"estrellas más. {nombre_1} y {nombre_2} tienen planeado sobrevivir hasta el siglo XXII. ¡Cuántas estrellas más habrán de comprar y nombrar juntos! Su meta es {numero_de_estrellas_deseadas}." +
      f"Sólo faltan {numero_de_estrellas_deseadas - edad_1 + edad_2}. ¡Vamos {nombre_1} y {nombre_2}! {nombre_1} y {nombre_2} son les mejores amigues. No hay duda alguna.")

# %% [markdown]
# ## Ejemplo 6: Operadores de comparación

# %%
var_1 = 34
var_2 = 12
var_3 = 23.24
var_4 = 23.56
var_5 = "OK"
var_6 = "ERROR"
var_7 = True
var_8 = False

# %%
var_1 > var_2

# %%
var_1 < var_2

# %%
var_1 >= var_4

# %%
var_5 == var_6

# %%
var_5 != var_6

# %%
var_7 == var_8

# %% [markdown]
# ## Ejemplo 7: Estructuras de control de flujo

# %%
var_1 = 4
var_2 = 5

# %%
if var_1 < var_2:
    print("El bloque se ha corrido")

# %%
if var_1 > var_2:
    print("El bloque se ha corrido")

print("Yo estoy afuera del bloque, y de todas maneras me van a llamar")

# %%
if var_1 > var_2:
    print("La condición se ha cumplido")
else:
    print("La condición no se ha cumplido, y por lo tanto yo me imprimo")

# %%
if var_1 > var_2:
    print("La primera condición se ha cumplido")
elif var_1 < var_2:
    print("La segunda condición se ha cumplido")
else:
    print("Las primeras dos comparaciones fueron Falsas")
